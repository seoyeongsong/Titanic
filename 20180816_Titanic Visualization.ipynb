# %%
import pandas as pd
import numpy as np
from plotnine import *

# %%
train = pd.read_csv('data/train.csv')
train.shape
# Out:
# (891, 12)

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
test = pd.read_csv('data/test.csv')
test.shape
# Out:
# (418, 11)

# %%
train.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
train.pivot_table(index=['Sex'], values=['Survived'])
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
(ggplot(train)
 + aes(x='Sex', y='Survived')
 + geom_col()
)
# Out:
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\positions\position.py:188: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   intervals = data[xminmax].drop_duplicates().as_matrix().flatten()
# <ggplot: (11982123)>

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train['Embarked'] = train['Embarked'].astype('category')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null category
# dtypes: category(1), float64(2), int64(5), object(4)
# memory usage: 77.6+ KB

# %%
(ggplot(train)
 + aes(x='Sex', y='Survived', fill='Embarked')
 + geom_col()
)
# Out:
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\positions\position.py:188: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   intervals = data[xminmax].drop_duplicates().as_matrix().flatten()
# <ggplot: (13195752)>

# %%
(ggplot(train)
 + aes(x='Age', y='Embarked', fill='Survived')
 + geom_point()
)
# Out:
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\layer.py:450: UserWarning: geom_point : Removed 177 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (11982165)>

# %%
(ggplot(train)
 + aes(x='Embarked', y='Survived', fill='Sex')
 + geom_col()
)
# Out:
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\positions\position.py:188: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   intervals = data[xminmax].drop_duplicates().as_matrix().flatten()
# <ggplot: (-9223372036841282479)>

# %%
import missingno as msno
msno.matrix(train)
# Out:
# C:\Users\home\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['HYnamM'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# C:\Users\home\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['HYnamM'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# C:\Users\home\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['HYnamM'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# C:\Users\home\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['HYnamM'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# ...

# %%
train.dropna?

# %%
# age에 결측치가 많기 때문에 이를 제거한다.

train = train.dropna()
train.shape
# 결측치를 모두 제거하였더니 891개 중 183개만 남았다.
# Out:
# (183, 12)

# %%
(ggplot(train)
 + aes(x='Sex', y='Survived', fill='Embarked')
 + geom_col()
)

# 그래프 상단의 파란색 부분이 모두 삭제됨
# Out:
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\positions\position.py:188: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   intervals = data[xminmax].drop_duplicates().as_matrix().flatten()
# <ggplot: (15241967)>

# %%
(ggplot(train)
 + aes(x='Age', y='Survived', fill='Embarked')
 + geom_bar(stat='identity')
)
# Out:
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\positions\position.py:188: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   intervals = data[xminmax].drop_duplicates().as_matrix().flatten()
# <ggplot: (15166272)>

# %%
(ggplot(train)
 + aes(x='Sex', y='Survived', fill='Pclass')
 + geom_col()
)
# Out:
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\positions\position.py:188: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   intervals = data[xminmax].drop_duplicates().as_matrix().flatten()
# <ggplot: (-9223372036839595106)>

# %%
train['Survived'] = train['Survived'].astype('category')

(ggplot(train)
 + aes(x='Sex', y='Survived')
 + geom_col()
 + ggtitle('성별 생존률')
 + theme(text=element_text(family='HYnamM'))
)
# Out:
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\positions\position.py:188: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   intervals = data[xminmax].drop_duplicates().as_matrix().flatten()
# ...

# %%
(ggplot(train)
 + aes(x='Age', y='Fare', fill='Pclass')
 + geom_point()
 + ggtitle('생존 여부별 성별 요금 등급 분포')
 + facet_wrap('~Survived')
 + theme(text=element_text(family='NanumBarunGothic'))
)
# Out:
# C:\Users\home\Anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\home\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\home\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# ...

# %%
# 결측치가 존재할 경우 평균값으로 대체할 수 있다.

# %%
test['Survived'] = 0

# %%
test.shape

# column 수가 1 늘어남
# Out:
# (418, 12)

# %%
test['Survived'] = test['Sex'] == 'female'

# %%
test['Survived'].value_counts()
# Out:
# False    266
# True     152
# Name: Survived, dtype: int64

# %%
test['Survived'] = ( test['Embarked'] == 'S') | ( test['Age'] <= 10 )

# %%
test['Survived'].value_counts()
# Out:
# True     276
# False    142
# Name: Survived, dtype: int64

# %%
test.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %%
submission = test[['PassengerId', 'Survived']].copy()

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892     False
# 1          893      True
# 2          894     False
# 3          895      True
# 4          896      True

# %%
submission.to_csv('submission_female_9.csv', index=False)

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
# PassengerId    418 non-null int64
# Survived       418 non-null int32
# dtypes: int32(1), int64(1)
# memory usage: 5.0 KB

# %%
# %ls
# Out:
#  C 드라이브의 볼륨: S3A4924D002
#  볼륨 일련 번호: 62EA-1054
#
#  C:\Users\home\dataitgirls\Titanic 디렉터리
#
# 2018-08-16  오후 04:30    <DIR>          .
# 2018-08-16  오후 04:30    <DIR>          ..
# 2018-08-16  오후 03:35                28 .gitignore
# 2018-08-16  오후 03:38    <DIR>          .ipynb_checkpoints
# 2018-08-16  오후 04:30           348,058 20180816_Titanic Visualization.ipynb
# 2018-08-16  오후 02:33    <DIR>          data
# 2018-08-13  오후 12:37             1,090 LICENSE
# 2018-08-13  오후 12:37                54 README.md
# 2018-08-16  오후 04:31             3,258 submission_female_9.csv,
# 2018-08-13  오후 12:34            27,127 Titanic.ipynb
#                6개 파일             379,615 바이트
#                4개 디렉터리  211,536,707,584 바이트 남음

# %%
submission['Survived'] = submission['Survived'].astype(int)

# %%
# %ls
# Out:
#  C 드라이브의 볼륨: S3A4924D002
#  볼륨 일련 번호: 62EA-1054
#
#  C:\Users\home\dataitgirls\Titanic 디렉터리
#
# 2018-08-16  오후 04:34    <DIR>          .
# 2018-08-16  오후 04:34    <DIR>          ..
# 2018-08-16  오후 03:35                28 .gitignore
# 2018-08-16  오후 03:38    <DIR>          .ipynb_checkpoints
# 2018-08-16  오후 04:34           349,037 20180816_Titanic Visualization.ipynb
# 2018-08-16  오후 02:33    <DIR>          data
# 2018-08-13  오후 12:37             1,090 LICENSE
# 2018-08-13  오후 12:37                54 README.md
# 2018-08-16  오후 04:31             3,258 submission_female_9.csv,
# 2018-08-13  오후 12:34            27,127 Titanic.ipynb
#                6개 파일             380,594 바이트
#                4개 디렉터리  211,536,531,456 바이트 남음

# %%
import pandas as pd

# %%
s = pd.read_csv('submission_female_9.csv')
s.shape
# Out:
# (418, 2)

# %%
s
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         1
# 4            896         1
# 5            897         1
# 6            898         0
# 7            899         1
# 8            900         0
# 9            901         1
# 10           902         1
# 11           903         1
# 12           904         1
# 13           905         1
# 14           906         1
# 15           907         0
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         0
# 20           912         0
# 21           913         1
# 22           914         1
# 23           915         0
# 24           916         0
# 25           917         1
# 26           918         0
# 27           919         0
# 28           920         1
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         1
# ...

# %%
test['Survived'] = ( test['Embarked'] == 'S')

# %%
test['Survived'].value_counts()
# Out:
# True     270
# False    148
# Name: Survived, dtype: int64

# %%
submission = test[['PassengerId', 'Survived']].copy()

# %%
submission['Survived'] = submission['Survived'].astype(int)

# %%
submission.to_csv('submission_Embarked.csv', index=False)

# %%
s = pd.read_csv('submission_Embarked.csv')
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
# PassengerId    418 non-null int64
# Survived       418 non-null int64
# dtypes: int64(2)
# memory usage: 6.6 KB
